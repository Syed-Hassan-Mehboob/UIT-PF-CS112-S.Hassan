# %%
print(119*'='+'=\nUSER INPUT:'+'\n-'+119*'-')

name,f_name=input('Enter your name: '),input("Enter your father's name: ")
print(120*'-')

x1,x2,x3=input('Enter the year you enrolled in UIT: '),input('Enter your roll number: '),input("Enter the short form of your deparment's name: ")
roll_no=(x1[2:]+'B-'+x2+'-'+x3.upper())
print(120*'-')

subjects,course_no,o_marks,t_marks=list(range(5)),list(range(5)),list(range(5)),list(range(5))
for i in range(5):
    subjects[i],course_no[i]=input('Enter the name of one of your subjects: '),input('Enter the course number of the above subject: ')
    o_marks[i],t_marks[i]=input('Enter your obtained marks in the above subject: '),input('Enter the total marks possible in the above subject: ')
    print()

print(119*'='+'=\nPROGRAM OUTPUT:')

print(119*'-'+'-\n'+52*' '+'UIT RESULT SHEET')
print(120*'-'+'\nSTUDENT NAME: '+name.upper()+'\nFATHER NAME: '+f_name.upper()+'\nROLL NUMBER :'+roll_no.upper()+'\n-'+119*'-')
print('{:<20}{:<20}{:<20}{:<20}{:<20}{:<20}'.format('SUBJECT','COURSE_NUMBER','OBTAINED_MARKS','TOTAL_MARKS','PERCENTAGE','GRADE'))

per=list(range(5))
for j in range(5):
    per[j]=((float(o_marks[j])*100)/float(t_marks[j]))
    if per[j]>=90:
        grade='A+'
    if per[j]<90 and per[j]>=80:
        grade='A'
    if per[j]<80 and per[j]>=70:
        grade='B'
    if per[j]<70 and per[j]>=60:
        grade='C'
    if per[j]<60 and per[j]>=50:
        grade='D'
    if per[j]<50:
        grade='F'
    print('{:<20}{:<20}{:<20}{:<20}{:<20}{:<20}'.format(subjects[j].upper(),course_no[j].upper(),float(o_marks[j]),float(t_marks[j]),(str(round(per[j],2))+'%'),grade))

if ((sum(per))/5)>=90:
    t_grade='A+'
if ((sum(per))/5)<90 and ((sum(per))/5)>=80:
    t_grade='A'
if ((sum(per))/5)<80 and ((sum(per))/5)>=70:
    t_grade='B'
if ((sum(per))/5)<70 and ((sum(per))/5)>=60:
    t_grade='C'
if ((sum(per))/5)<60 and ((sum(per))/5)>=50:
    t_grade='D'
if ((sum(per))/5)<50:
    t_grade='F'

print('\n-'+118*'-'+'-\nTOTAL PERCENTAGE: '+str(round(((sum(per))/5),2))+'%'+'\nTOTAL GRADE: '+t_grade+'\n='+119*'=')
# Out:
# ...
# USER INPUT:
# ------------------------------------------------------------------------------------------------------------------------
# Enter your name: Syed Hassan Mehboob
# Enter your father's name: Syed Mahboob Akhter
# ------------------------------------------------------------------------------------------------------------------------
# Enter the year you enrolled in UIT: 2020
# Enter your roll number: 35
# Enter the short form of your deparment's name: se
# ------------------------------------------------------------------------------------------------------------------------
# Enter the name of one of your subjects: calculus
# Enter the course number of the above subject: ms111
# Enter your obtained marks in the above subject: 89
# Enter the total marks possible in the above subject: 100
#
# Enter the name of one of your subjects: programming
# Enter the course number of the above subject: cs112
# Enter your obtained marks in the above subject: 140
# ...
