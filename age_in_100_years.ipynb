# %%
name = input("Please enter your name: ")
age = int(input("Please enter your age: "))
current_year = int(input("Please enter the current year: "))
year = str((current_year - age) + 100)
print("~ " + name + " will be 100 years old in the year " + year)
# Out:
# Please enter your name:  Syed Hassan Mehboob
# Please enter your age:  17
# Please enter the current year:  2020
# ~ Syed Hassan Mehboob will be 100 years old in the year 2103
