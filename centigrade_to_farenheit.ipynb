# %%
centigrade = float(input("Enter the value of °centigrade: "))
centigrade_str = str(centigrade)
farenheit = ((centigrade * 1.8) + 32)
farenheit_str = str(farenheit)
print(centigrade_str + "°" + " centigrades is equal to " + farenheit_str + "° farenheits")
# Out:
# Enter the value of °centigrade:  -65.7
# -65.7° centigrades is equal to -86.26° farenheits
